# %%
import time
start_time = time.time()
import numpy as np
import matplotlib.pyplot as plt
import skrf as rf

# %%
ntwk = rf.Network('dualpolar_0409_HFSSDesign1.s1p')
ntwk.plot_s_smith()

# %%
ntwk.plot_s_db()

# %%
ntwk.z.shape
# Out:
# (1001, 1, 1)
