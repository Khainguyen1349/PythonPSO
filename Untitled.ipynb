# %%
import time
start_time = time.time()
import numpy as np
import matplotlib.pyplot as plt
import skrf as rf

# %%
ntwk = rf.Network('700_960_MHz_IFA.s1p')
ntwk.plot_s_smith()

# %%
ntwk.plot_s_db()

# %%
ntwk.z.shape
# Out:
# (1001, 1, 1)

# %%
ntwk.frequency[2].center
# Out:
# 4000000.0

# %%
ntwk
# Out:
# 1-Port Network: 'dualpolar_0409_HFSSDesign1',  1.0-6.0 GHz, 1001 pts, z0=[50.+0.j]
